# %%
# Initial imports

import requests

# %%
# Importing data as json

url1 = "https://nonfungible.com/api/v1/market/cryptopunks/history/?start=0length=1&datatype=json&columns[0][name]=blockTimestamp&order[0][dir]=asc"

# %%
requests.get(url1)
# Out:
# <Response [200]>

# %%
# Execute GET request and store response

response_data = requests.get(url1)

# %%
print(type(response_data))
# Out:
# <class 'requests.models.Response'>

# %%
# Get content 

response_content = response_data.content

print(response_content)
# Out:
# b'<!DOCTYPE html><html><head><script src="/cdn-cgi/apps/head/PqxrA7H5tv_wmbB_7rOurFvkEqw.js"></script><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="anonymous" /><link rel="preload" as="style" href="https://fonts.googleapis.com/css2?family=IBM+Plex+Sans:wght@400;500&amp;family=Yantramanav:wght@400;500&amp;family=Roboto:wght@300;400;500;700&amp;display=swap" /><link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Sans:wght@400;500&amp;family=Yantramanav:wght@400;500&amp;family=Roboto:wght@300;400;500;700&amp;display=swap" rel="stylesheet" media="print" /><title>Home</title><meta name="description" content="" /><meta name="keywords" content="" /><meta property="og:url" content="" /><meta property="og:title" content="Home" /><meta property="og:description" content="" /><meta name="twitter:site" content="" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:image" content="" /><meta property="og:image" content="" /><meta property=
# ...

# %%
requests.get

# %%
#Create variable to hold request url

url = "https://nonfungible.com/api/v1/market/cryptopunks/history/?start=0length=1&columns[0][name]=blockTimestamp&order[0][dir]=asc"

# %%
# Add format specifier to request URL

url = url + "?format=json"
url
# Out:
# 'https://nonfungible.com/api/v1/market/cryptopunks/history/?start=0length=1&columns[0][name]=blockTimestamp&order[0][dir]=asc?format=json'

# %%
# Execute GET request

requests.get(url)
# Out:
# <Response [200]>

# %%
requests.get("https://nonfungible.com/api/v1/market/cryptopunks/history/?start=0length=1&columns[0][name]=blockTimestamp&order[0][dir]=asc").json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-27-826a0ab247a2> in <module>
# ----> 1 requests.get("https://nonfungible.com/api/v1/market/cryptopunks/history/?start=0length=1&columns[0][name]=blockTimestamp&order[0][dir]=asc").json()
#
# ~\anaconda3\ANACONDA\envs\pyvizenv\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\ANACONDA\envs\pyvizenv\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
# Execute GET request and store response

response_data = requests.get(url)

# %%
print(type(response_data))
# Out:
# <class 'requests.models.Response'>

# %%
# Get content 

response_content = response_data.content

print(response_content)
# Out:
# b'<!DOCTYPE html><html><head><script src="/cdn-cgi/apps/head/PqxrA7H5tv_wmbB_7rOurFvkEqw.js"></script><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="anonymous" /><link rel="preload" as="style" href="https://fonts.googleapis.com/css2?family=IBM+Plex+Sans:wght@400;500&amp;family=Yantramanav:wght@400;500&amp;family=Roboto:wght@300;400;500;700&amp;display=swap" /><link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Sans:wght@400;500&amp;family=Yantramanav:wght@400;500&amp;family=Roboto:wght@300;400;500;700&amp;display=swap" rel="stylesheet" media="print" /><title>Home</title><meta name="description" content="" /><meta name="keywords" content="" /><meta property="og:url" content="" /><meta property="og:title" content="Home" /><meta property="og:description" content="" /><meta name="twitter:site" content="" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:image" content="" /><meta property="og:image" content="" /><meta property=
# ...

# %%
print(type(response_content))
# Out:
# <class 'bytes'>

# %%
# import json library 

# import json

# %%
# Attempts to convert to json 

jsonResponse = json.loads(response_content.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-26-c1ae1d18b701> in <module>
#       1 # Attempts to convert to json
#       2
# ----> 3 jsonResponse = json.loads(response_content.decode('utf-8'))
#
# ~\anaconda3\ANACONDA\envs\pyvizenv\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\ANACONDA\envs\pyvizenv\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...

# %%
# Format data as a raw json file

data = response_content.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-63c67295800d> in <module>
#       1 # Format data as a raw json file
#       2
# ----> 3 data = response_content.json()
#
# AttributeError: 'bytes' object has no attribute 'json'

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-dbd883db58b7> in <module>
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %%
print(type(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ea83332336b0> in <module>
# ----> 1 print(type(data))
#
# NameError: name 'data' is not defined

# %%
# Add indents to JSON and output to screen

import json
print(json.dumps(data, indent=4))

# %%
print(type(json.dumps(data, indent=4)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-17fb294e7a97> in <module>
# ----> 1 print(type(json.dumps(data, indent=4)))
#
# NameError: name 'data' is not defined

# %%
# Identify first data 

data[1]

# %%
print(type(data[1][1]))
